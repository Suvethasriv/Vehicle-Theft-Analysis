# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('E:\Data.csv')

# %%
train.head()
# Out:
#      State  Rank                    Make/Model  Model Year  Thefts
# 0  Alabama     1  Chevrolet Pickup (Full Size)        2005     499
# 1  Alabama     2       Ford Pickup (Full Size)        2006     357
# 2  Alabama     3                  Toyota Camry        2014     205
# 3  Alabama     4                 Nissan Altima        2014     191
# 4  Alabama     4              Chevrolet Impala        2004     191

# %%
print(train.columns.values)
# Out:
# ['State' 'Rank' 'Make/Model' 'Model Year' 'Thefts']

# %%
train.isna().head()
# Out:
#    State   Rank  Make/Model  Model Year  Thefts
# 0  False  False       False       False   False
# 1  False  False       False       False   False
# 2  False  False       False       False   False
# 3  False  False       False       False   False
# 4  False  False       False       False   False

# %%
print("*****In the train set*****")
print(train.isna().sum())
print("\n")
# Out:
# *****In the train set*****
# State         0
# Rank          0
# Make/Model    0
# Model Year    0
# Thefts        0
# dtype: int64

# %%
train.fillna(train.mean(), inplace=True)

# %%
print(train.isna().sum())
# Out:
# State         0
# Rank          0
# Make/Model    0
# Model Year    0
# Thefts        0
# dtype: int64

# %%
train['State'].head()
# Out:
# 0    Alabama
# 1    Alabama
# 2    Alabama
# 3    Alabama
# 4    Alabama
# Name: State, dtype: object

# %%
train['Thefts'].head()
# Out:
# 0    499
# 1    357
# 2    205
# 3    191
# 4    191
# Name: Thefts, dtype: int64

# %%
train[['State', 'Rank']].groupby(['State'], as_index=False).mean().sort_values(by='Rank', ascending=False)
# Out:
#                    State  Rank
# 25              Missouri   5.5
# 33        North Carolina   5.5
# 24           Mississippi   5.5
# 1                 Alaska   5.5
# 26               Montana   5.5
# 27              Nebraska   5.5
# 28                Nevada   5.5
# 30            New Jersey   5.5
# 31            New Mexico   5.5
# 32              New York   5.5
# 34          North Dakota   5.5
# 22              Michigan   5.5
# 35                  Ohio   5.5
# 36              Oklahoma   5.5
# 37                Oregon   5.5
# 38          Pennsylvania   5.5
# 39          Rhode Island   5.5
# 40        South Carolina   5.5
# 43                 Texas   5.5
# 44                  Utah   5.5
# 46              Virginia   5.5
# 23             Minnesota   5.5
# 21         Massachusetts   5.5
# 11                Hawaii   5.5
# 2                Arizona   5.5
# 3               Arkansas   5.5
# 4             California   5.5
# 5               Colorado   5.5
# 6            Connecticut   5.5
# ...

# %%
train.corr()
# Out:
#                 Rank  Model Year    Thefts
# Rank        1.000000    0.168044 -0.165138
# Model Year  0.168044    1.000000 -0.069855
# Thefts     -0.165138   -0.069855  1.000000

# %%
train.apply(lambda x: x.count(), axis=1)
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
# 5      5
# 6      5
# 7      5
# 8      5
# 9      5
# 10     5
# 11     5
# 12     5
# 13     5
# 14     5
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     5
# 23     5
# 24     5
# 25     5
# 26     5
# 27     5
# 28     5
# 29     5
#       ..
# 480    5
# 481    5
# 482    5
# 483    5
# 484    5
# 485    5
# 486    5
# 487    5
# 488    5
# 489    5
# 490    5
# 491    5
# 492    5
# 493    5
# 494    5
# 495    5
# 496    5
# 497    5
# 498    5
# 499    5
# 500    5
# 501    5
# 502    5
# 503    5
# 504    5
# 505    5
# 506    5
# 507    5
# 508    5
# 509    5
# Length: 510, dtype: int64

# %%
train.isnull()
# Out:
#      State   Rank  Make/Model  Model Year  Thefts
# 0    False  False       False       False   False
# 1    False  False       False       False   False
# 2    False  False       False       False   False
# 3    False  False       False       False   False
# 4    False  False       False       False   False
# 5    False  False       False       False   False
# 6    False  False       False       False   False
# 7    False  False       False       False   False
# 8    False  False       False       False   False
# 9    False  False       False       False   False
# 10   False  False       False       False   False
# 11   False  False       False       False   False
# 12   False  False       False       False   False
# 13   False  False       False       False   False
# 14   False  False       False       False   False
# 15   False  False       False       False   False
# 16   False  False       False       False   False
# 17   False  False       False       False   False
# ...

# %%
missing_values = ["n/a", "na", "--"]
train = pd.read_csv("E:\Data.csv", na_values = missing_values)

# %%
train.isnull()
# Out:
#      State   Rank  Make/Model  Model Year  Thefts
# 0    False  False       False       False   False
# 1    False  False       False       False   False
# 2    False  False       False       False   False
# 3    False  False       False       False   False
# 4    False  False       False       False   False
# 5    False  False       False       False   False
# 6    False  False       False       False   False
# 7    False  False       False       False   False
# 8    False  False       False       False   False
# 9    False  False       False       False   False
# 10   False  False       False       False   False
# 11   False  False       False       False   False
# 12   False  False       False       False   False
# 13   False  False       False       False   False
# 14   False  False       False       False   False
# 15   False  False       False       False   False
# 16   False  False       False       False   False
# 17   False  False       False       False   False
# ...

# %%
print (train.isnull().sum())
# Out:
# State         0
# Rank          0
# Make/Model    0
# Model Year    0
# Thefts        0
# dtype: int64

# %%
print (train.isnull().values.any())
# Out:
# False

# %%
print (train.isnull().sum().sum())
# Out:
# 0

# %%
null_columns=train.columns[train.isnull().any()]

# %%
print(train[train["State"].isnull()][null_columns])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(train[train["Thefts"].isnull()][null_columns])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(train[train["Rank"].isnull()][null_columns])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
median_value=train["Rank"].median()

# %%
train["Rank"]=train["Rank"].fillna(median_value)

# %%
print(train[train["Make/Model"].isnull()][null_columns])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print (train.isnull().sum())
# Out:
# State         0
# Rank          0
# Make/Model    0
# Model Year    0
# Thefts        0
# dtype: int64
